# %% [markdown]
# split data intou 2

# %%
import pandas as pd

# %%
import botometer

rapidapi_key = "32d259caa4msh1d28e111b7320b3p13c365jsn290859214dbc"

consumer_key="tH7AnhdvgOndxvZOyeeyfHOVG"
consumer_secret="14mR3PZn3osH1OBPjtJWJT7IycQB5kOF4PmIuDjHvFHuEZppk0"
twitter_app_auth = {
    'consumer_key':consumer_key,
    'consumer_secret':consumer_secret ,   
  }
bom = botometer.Botometer(wait_on_ratelimit=True,
                          rapidapi_key=rapidapi_key,
                          **twitter_app_auth)

# Check a single account by screen name
result = bom.check_account('@TrollFootball')

english_score = result['cap']['english']
universal_score = result['cap']['universal']
general_score =5 -((english_score + universal_score) / 2)
# Out:
# {'cap': {'english': 0.7470839770895665, 'universal': 0.8052176344738626}, 'display_scores': {'english': {'astroturf': 0.4, 'fake_follower': 1.6, 'financial': 0.0, 'other': 2.9, 'overall': 1.2, 'self_declared': 0.2, 'spammer': 0.1}, 'universal': {'astroturf': 0.4, 'fake_follower': 0.8, 'financial': 0.2, 'other': 3.2, 'overall': 3.2, 'self_declared': 0.2, 'spammer': 0.1}}, 'raw_scores': {'english': {'astroturf': 0.07, 'fake_follower': 0.33, 'financial': 0.01, 'other': 0.58, 'overall': 0.25, 'self_declared': 0.05, 'spammer': 0.02}, 'universal': {'astroturf': 0.07, 'fake_follower': 0.15, 'financial': 0.03, 'other': 0.63, 'overall': 0.63, 'self_declared': 0.05, 'spammer': 0.02}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '571964518', 'screen_name': 'TrollFootball'}}}

# %%
result = bom.check_account('@the_kingslife')

# Check a single account by id
# result = bom.check_account(1548959833)
print(result)
# Out:
# {'cap': {'english': 0.7907586934369296, 'universal': 0.8115094045580712}, 'display_scores': {'english': {'astroturf': 0.2, 'fake_follower': 1.1, 'financial': 0.0, 'other': 3.2, 'overall': 1.8, 'self_declared': 3.2, 'spammer': 0.7}, 'universal': {'astroturf': 0.1, 'fake_follower': 1.1, 'financial': 0.0, 'other': 3.8, 'overall': 3.8, 'self_declared': 3.2, 'spammer': 0.7}}, 'raw_scores': {'english': {'astroturf': 0.04, 'fake_follower': 0.22, 'financial': 0.01, 'other': 0.64, 'overall': 0.36, 'self_declared': 0.63, 'spammer': 0.14}, 'universal': {'astroturf': 0.02, 'fake_follower': 0.22, 'financial': 0.01, 'other': 0.76, 'overall': 0.76, 'self_declared': 0.65, 'spammer': 0.14}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1585621392573317122', 'screen_name': 'the_kingslife'}}}

# %%
# read DataFrame
df = pd.read_csv("./Data/cleandatafromAPI.csv")

# %%
k = 2
size = 17023
data = pd.read_csv("./Data/cleandatafromAPI.csv")
for i in range(k):
    df = data[size*i:size*(i+1)]
    df.to_csv(f'data{i+1}.csv', index=False)
consumer_key1= 'txGKpZibczbB3viciPGaIht1h'
consumer_secret1= 'LdBcAwDspNV2IoGdBrDC5wTiprqW4LiHPFTOWcq95a9FgkWc5M'
access_token1= '1622613622860967937-HtuI8jqgHy8P5fJgN1EKGLqqDqWCOw'
access_token_secret1= 'uEpId3rtrIdNZe9iylsohsu7xvoMHs8NHgfNOndfgh6Me'
bearer_token1="AAAAAAAAAAAAAAAAAAAAAJ%2BwlgEAAAAAApXZ%2BQkCOMMCUz8yA0Q2U7cIx4A%3D54C8m6MSpNmM1g4oeEH5ZpzknYFfJ4zYSWSaxVteTpfofyg5Ni"
rapidapi_key1 ="99ba8c7fcemshe47fdb473278300p152fa7jsn2a114ad217c5"

# %%
df
# Out:
#                                                    image  \
# 0      https://pbs.twimg.com/profile_images/145899544...
# 1      https://pbs.twimg.com/profile_images/632916759...
# 2      https://pbs.twimg.com/profile_images/158696080...
# 3      https://pbs.twimg.com/profile_images/977012905...
# 4      https://pbs.twimg.com/profile_images/668449819...
# ...                                                  ...
# 34039  https://pbs.twimg.com/profile_images/712018970...
# 34040  https://pbs.twimg.com/profile_images/141825399...
# 34041  https://pbs.twimg.com/profile_images/142309872...
# 34042  https://pbs.twimg.com/profile_images/157735786...
# 34043  https://pbs.twimg.com/profile_images/160574287...
#
#                                         background_image  verified  statuses  \
# 0      http://abs.twimg.com/images/themes/theme11/bg.gif     False      7098
# 1       http://abs.twimg.com/images/themes/theme3/bg.gif     False       270
# ...
