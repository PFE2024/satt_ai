# %%
import pandas as pd
from Twitterpreprocessor import TwitterPreprocessor
from sklearn.feature_extraction.text import CountVectorizer
data = pd.read_csv("./twitterdataset/twitter_human_bots_dataset1.csv")
data =data.drop(['Unnamed: 0','geo_enabled','default_profile','default_profile_image','account_age_days','profile_image_path','profile_background_image_path','split'], axis=1)
data["account_type"].value_counts()
# Out:
# human    25013
# bot      12425
# Name: account_type, dtype: int64

# %% [markdown]
# # delet columns that contains nan values

# %%
#delet columns that contains nan values
data = data.dropna(axis=1, how='all')
#delet rows that contains nan values
# data = data.dropna()
data=data.drop_duplicates(subset="screen_name",keep='first')
data
# Out:
#                 created_at                                        description  \
# 0      2009-07-04 22:41:51                                                NaN
# 1      2010-01-17 22:54:19  Television producer. Emmy Award winner. Disney...
# 2      2012-03-01 06:05:32                                                NaN
# 3      2009-09-01 04:52:30                                                NaN
# 4      2010-01-27 17:17:23  Productor de Televisión - Embajador de @Tienda...
# ...                    ...                                                ...
# 37433  2010-12-07 08:11:16  Self Made Plus Model, #BeautyIsNotASize, CEO @...
# 37434  2010-12-04 13:17:22  Gazeteci/Journalist                           ...
# 37435  2009-10-06 23:53:30  Modelo y Actriz Venezolana/ Venezuelan Model &...
# 37436  2013-03-24 21:04:16                   Indian!...Actor!...Need no more!
# 37437  2011-01-10 04:01:02  📖Poeta, Autor, Escritor, dois Livros Publicado...
#
#        favourites_count  followers_count  friends_count          id lang  \
# 0                  5007              102            168    53779179  NaN
# 1                  1038               60            128   105916557   en
# 2                  2257              599            449   509788597  NaN
# 3                  6407              116            334    70601327  NaN
# 4                 20866            74448             18   108999927   es
# ...                 ...              ...            ...         ...  ...
# 37433             59660           257294            196   223764929   en
# 37434                 0            74666             95   222789645   sv
# 37435                28           255941            236    80438218   es
# 37436               621          2678042             51  1296642259   en
# 37437              4526           471451          15967   236242525   pt
#
#                        location  \
# 0               Maringá, Brasil
# 1                       Atlanta
# 2                       unknown
# 3                  Brooklyn, NY
# 4                     Miami, FL
# ...                         ...
# 37433  Los Angeles & Eastern PA
# 37434                   unknown
# 37435                   unknown
# 37436                 Hyderabad
# 37437      Minas Gerais, Brasil
#
#                             profile_background_image_url  \
# 0      https://abs.twimg.com/images/themes/theme11/bg...
# 1      https://abs.twimg.com/images/themes/theme3/bg.gif
# 2      https://abs.twimg.com/images/themes/theme1/bg.png
# 3      https://abs.twimg.com/images/themes/theme6/bg.gif
# 4      https://abs.twimg.com/images/themes/theme14/bg...
# ...                                                  ...
# 37433  https://abs.twimg.com/images/themes/theme14/bg...
# 37434  https://abs.twimg.com/images/themes/theme9/bg.gif
# 37435  https://abs.twimg.com/images/themes/theme10/bg...
# 37436  https://abs.twimg.com/images/themes/theme1/bg.png
# 37437  https://abs.twimg.com/images/themes/theme1/bg.png
#
#                                        profile_image_url      screen_name  \
# 0      https://pbs.twimg.com/profile_images/128969130...     paty_castroo
# 1      https://pbs.twimg.com/profile_images/632916759...        CBirckner
# 2      https://pbs.twimg.com/profile_images/128853844...          amf_jay
# 3      https://pbs.twimg.com/profile_images/977012905...       SaraCavolo
# 4      https://pbs.twimg.com/profile_images/668449819...  DavidHenaoModel
# ...                                                  ...              ...
# 37433  https://pbs.twimg.com/profile_images/712018970...       AshAlexiss
# 37434  https://pbs.twimg.com/profile_images/127353595...          ahmemis
# 37435  https://pbs.twimg.com/profile_images/114651544...  Yuvannamontalvo
# 37436  https://pbs.twimg.com/profile_images/129570440...      IAmVarunTej
# 37437  https://pbs.twimg.com/profile_images/129213145...       tiagopoeta
#
#        statuses_count  verified  average_tweets_per_day account_type
# 0                3974     False                   0.978          bot
# 1                 259     False                   0.067        human
# 2               13627     False                   4.406        human
# 3                4432     False                   1.107        human
# 4               15870      True                   4.116        human
# ...               ...       ...                     ...          ...
# 37433           58680      True                  16.562        human
# 37434           41240      True                  11.633        human
# 37435            6692     False                   1.686        human
# 37436            2042      True                   0.755        human
# 37437           11597     False                   3.305        human
#
# [37438 rows x 15 columns]

# %% [markdown]
# # preprocessor

# %%
data['description'] = data['description'].apply(lambda x :TwitterPreprocessor(str(x)).fully_preprocess().text)
data['location'] = data['location'].apply(lambda x :TwitterPreprocessor(str(x)).partially_preprocess().text)
data
# Out:
#                 created_at                                        description  \
# 0      2009-07-04 22:41:51
# 1      2010-01-17 22:54:19  television producer emmy award winner disney e...
# 2      2012-03-01 06:05:32
# 3      2009-09-01 04:52:30
# 4      2010-01-27 17:17:23  productor televisin embajador contacto dreamco...
# ...                    ...                                                ...
# 37433  2010-12-07 08:11:16            self made plus model swim traveler wife
# 37434  2010-12-04 13:17:22           gazetecijournalist haberdarda koordinatr
# 37435  2009-10-06 23:53:30  modelo actriz venezolana venezuelan model actr...
# 37436  2013-03-24 21:04:16                                    indianactorneed
# 37437  2011-01-10 04:01:02  poeta autor escritor dois livros publicados de...
#
#        favourites_count  followers_count  friends_count          id lang  \
# 0                  5007              102            168    53779179  NaN
# 1                  1038               60            128   105916557   en
# 2                  2257              599            449   509788597  NaN
# 3                  6407              116            334    70601327  NaN
# 4                 20866            74448             18   108999927   es
# ...                 ...              ...            ...         ...  ...
# 37433             59660           257294            196   223764929   en
# 37434                 0            74666             95   222789645   sv
# 37435                28           255941            236    80438218   es
# 37436               621          2678042             51  1296642259   en
# 37437              4526           471451          15967   236242525   pt
#
#                      location  \
# 0               Maring Brasil
# 1                     Atlanta
# 2                     unknown
# 3                 Brooklyn NY
# 4                    Miami FL
# ...                       ...
# 37433  Los Angeles Eastern PA
# 37434                 unknown
# 37435                 unknown
# 37436               Hyderabad
# 37437     Minas Gerais Brasil
#
#                             profile_background_image_url  \
# 0      https://abs.twimg.com/images/themes/theme11/bg...
# 1      https://abs.twimg.com/images/themes/theme3/bg.gif
# 2      https://abs.twimg.com/images/themes/theme1/bg.png
# 3      https://abs.twimg.com/images/themes/theme6/bg.gif
# 4      https://abs.twimg.com/images/themes/theme14/bg...
# ...                                                  ...
# 37433  https://abs.twimg.com/images/themes/theme14/bg...
# 37434  https://abs.twimg.com/images/themes/theme9/bg.gif
# 37435  https://abs.twimg.com/images/themes/theme10/bg...
# 37436  https://abs.twimg.com/images/themes/theme1/bg.png
# 37437  https://abs.twimg.com/images/themes/theme1/bg.png
#
#                                        profile_image_url      screen_name  \
# 0      https://pbs.twimg.com/profile_images/128969130...     paty_castroo
# 1      https://pbs.twimg.com/profile_images/632916759...        CBirckner
# 2      https://pbs.twimg.com/profile_images/128853844...          amf_jay
# 3      https://pbs.twimg.com/profile_images/977012905...       SaraCavolo
# 4      https://pbs.twimg.com/profile_images/668449819...  DavidHenaoModel
# ...                                                  ...              ...
# 37433  https://pbs.twimg.com/profile_images/712018970...       AshAlexiss
# 37434  https://pbs.twimg.com/profile_images/127353595...          ahmemis
# 37435  https://pbs.twimg.com/profile_images/114651544...  Yuvannamontalvo
# 37436  https://pbs.twimg.com/profile_images/129570440...      IAmVarunTej
# 37437  https://pbs.twimg.com/profile_images/129213145...       tiagopoeta
#
#        statuses_count  verified  average_tweets_per_day account_type
# 0                3974     False                   0.978          bot
# 1                 259     False                   0.067        human
# 2               13627     False                   4.406        human
# 3                4432     False                   1.107        human
# 4               15870      True                   4.116        human
# ...               ...       ...                     ...          ...
# 37433           58680      True                  16.562        human
# 37434           41240      True                  11.633        human
# 37435            6692     False                   1.686        human
# 37436            2042      True                   0.755        human
# 37437           11597     False                   3.305        human
#
# [37438 rows x 15 columns]

# %% [markdown]
# # save data

# %%
data.to_csv('cleandata.csv', index=False)

# %% [markdown]
# # descover data

# %%
data =data.reset_index()
data
df=pd.DataFrame(data)
df.head()
# Out:
#    index           created_at  \
# 0      0  2009-07-04 22:41:51
# 1      1  2010-01-17 22:54:19
# 2      2  2012-03-01 06:05:32
# 3      3  2009-09-01 04:52:30
# 4      4  2010-01-27 17:17:23
#
#                                          description  favourites_count  \
# 0                                                                 5007
# 1  television producer emmy award winner disney e...              1038
# 2                                                                 2257
# 3                                                                 6407
# 4  productor televisin embajador contacto dreamco...             20866
#
#    followers_count  friends_count         id lang       location  \
# 0              102            168   53779179  NaN  Maring Brasil
# 1               60            128  105916557   en        Atlanta
# 2              599            449  509788597  NaN        unknown
# 3              116            334   70601327  NaN    Brooklyn NY
# 4            74448             18  108999927   es       Miami FL
#
#                         profile_background_image_url  \
# 0  https://abs.twimg.com/images/themes/theme11/bg...
# 1  https://abs.twimg.com/images/themes/theme3/bg.gif
# 2  https://abs.twimg.com/images/themes/theme1/bg.png
# 3  https://abs.twimg.com/images/themes/theme6/bg.gif
# 4  https://abs.twimg.com/images/themes/theme14/bg...
#
#                                    profile_image_url      screen_name  \
# 0  https://pbs.twimg.com/profile_images/128969130...     paty_castroo
# 1  https://pbs.twimg.com/profile_images/632916759...        CBirckner
# 2  https://pbs.twimg.com/profile_images/128853844...          amf_jay
# 3  https://pbs.twimg.com/profile_images/977012905...       SaraCavolo
# 4  https://pbs.twimg.com/profile_images/668449819...  DavidHenaoModel
#
#    statuses_count  verified  average_tweets_per_day account_type
# 0            3974     False                   0.978          bot
# 1             259     False                   0.067        human
# 2           13627     False                   4.406        human
# 3            4432     False                   1.107        human
# 4           15870      True                   4.116        human

# %%
df["account_type"].value_counts()
# Out:
# human    25013
# bot      12425
# Name: account_type, dtype: int64

# %%
x = df.description.values.tolist()


vectorizer = CountVectorizer()
data1 = vectorizer.fit_transform(x)
data1
# Out:
# <37438x42140 sparse matrix of type '<class 'numpy.int64'>'
# 	with 185490 stored elements in Compressed Sparse Row format>
