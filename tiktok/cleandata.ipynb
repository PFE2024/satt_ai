# %%
import pandas as pd

# %% [markdown]
# # get data

# %%
acounts = pd.read_csv("./tiktokdataset/accounts.txt",sep='\t')

videos = pd.read_csv("./tiktokdataset/videos.txt",sep='\t')
acounts
# Out:
#                                          Id  IsAccountPrivate  IsVerified  \
# 0      A9D326A9-2CB9-4396-897C-000188C0A54E             False       False
# 1      9A60337F-64D3-468F-A20F-0017CD58C59A              True       False
# 2      A4919958-31BA-4813-9B70-0017E92527C7             False       False
# 3      4026CA43-1F0D-42C7-AA7F-001E55ECB80A             False       False
# 4      7EE88B39-58A2-4CBF-8D32-001FAC568DA2             False       False
# ...                                     ...               ...         ...
# 10116  B57EC2B8-F088-40FA-9D78-FFDDBB506C68             False       False
# 10117  604FA15E-5515-4E4C-9A8D-FFEC1BE5A751             False       False
# 10118  6D14BDD3-59AD-486D-9DF1-FFF31B0ACDDF             False       False
# 10119  75109934-086C-49CD-B36B-FFF33C97CFBF             False       False
# 10120  C6020ECB-91AF-4E84-8F5A-FFFAEFC433FB             False       False
#
#       HasProfilePicture  AnzahlFolgeIch  AnzahlFollower AnzahlLikes  \
# 0                  True              63               0           0
# 1                  True             108               6          34
# 2                  True            3171              93           3
# 3                  True             245             145         471
# 4                  True            2255             132          78
# ...                 ...             ...             ...         ...
# 10116             False              36               4           0
# 10117             False             320               4           0
# 10118              True             314               3           0
# 10119              True             495               4           0
# 10120              True             245              11           6
#
#        HasInstagramLink  HasYoutubeLink HasAccountDescription  ...  \
# 0                 False           False                 False  ...
# 1                 False           False                 False  ...
# 2                 False           False                 False  ...
# 3                 False            True                  True  ...
# 4                 False           False                  True  ...
# ...                 ...             ...                   ...  ...
# 10116             False           False                 False  ...
# 10117             False           False                 False  ...
# 10118             False           False                 False  ...
# 10119             False           False                 False  ...
# 10120             False           False                  True  ...
#
#       LikedAverageNumberOfCharacters LikedAverageNumberOfForwardings  \
# 0                          57.800000                      198.200000
# 1                           0.000000                        0.000000
# 2                          65.400000                       68.200000
# 3                           0.000000                        0.000000
# 4                          49.333333                        1.333333
# ...                              ...                             ...
# 10116                       0.000000                        0.000000
# 10117                       0.000000                        0.000000
# 10118                      57.750000                        9.650000
# 10119                      63.050000                        1.450000
# 10120                       0.000000                        0.000000
#
#       LikedAverageNumberOfLikes LikedAverageNumberOfLinkedProfiles  \
# 0                  24550.100000                                0.0
# 1                      0.000000                                0.0
# 2                   2782.050000                               0.25
# 3                      0.000000                                0.0
# 4                    194.888889                 0.1111111111111111
# ...                         ...                                ...
# 10116                  0.000000                                0.0
# 10117                  0.000000                                0.0
# 10118                400.650000                               0.05
# 10119                416.350000                                0.2
# 10120                  0.000000                                0.0
#
#       LikedAverageNumberOfUsedFilters  AverageNumberOfViews  \
# 0                                 0.2              0.000000
# 1                                 0.0              0.000000
# 2                                0.15             21.000000
# 3                                 0.0             25.200000
# 4                  0.2222222222222222            557.666667
# ...                               ...                   ...
# 10116                             0.0              0.000000
# 10117                             0.0              0.000000
# 10118                             0.2              0.000000
# 10119                             0.2              0.000000
# 10120                             0.0              7.800000
#
#        LikedAverageNumberOfViews  VerhaeltnisLikesProAufruf  \
# 0                  152410.000000                        0.0
# 1                       0.000000                        0.0
# 2                   19475.100000        0.14285714285714285
# 3                       0.000000         0.1527777777777778
# 4                    1300.111111         0.0466228332337119
# ...                          ...                        ...
# 10116                   0.000000                        0.0
# 10117                   0.000000                        0.0
# 10118               17293.300000                        0.0
# 10119                5033.000000                        0.0
# 10120                   0.000000        0.15384615384615385
#
#        VerhaeltnisCommentsProAufruf  IsABot
# 0                               0.0    True
# 1                               0.0     NaN
# 2                               0.0    True
# 3                               0.0     NaN
# 4                               0.0    True
# ...                             ...     ...
# 10116                           0.0     NaN
# 10117                           0.0     NaN
# 10118                           0.0    True
# 10119                           0.0    True
# 10120                           0.0     NaN
#
# [10121 rows x 37 columns]

# %%
acounts["IsABot"].value_counts(dropna=False)
# Out:
# NaN      7140
# True     1786
# False    1195
# Name: IsABot, dtype: int64
